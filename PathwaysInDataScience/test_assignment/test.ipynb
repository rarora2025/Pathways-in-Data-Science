# %% [markdown]
# # Test Assignment
#
# Run all of the cells. Make sure to follow the directions in the second cell.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# replace MYNAME with your actual name
name = "Rahul"
print(f"Hi, my name is {name}")
# Out:
# Hi, my name is Rahul

# %%
arr = np.linspace(0, 2 * np.pi, 100)
sin = np.sin(arr)
plt.plot(arr, sin)

# %%
A = np.random.normal(size = (1000, 1000))
t0 = time.time()
Ainv = np.linalg.inv(A)
t1 = time.time()

print(f"took {t1 - t0}s")
# Out:
# took 0.07902312278747559s
